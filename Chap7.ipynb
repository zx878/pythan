# %% [markdown]
# ## Chap7錯誤修理
#
#  * try
#  * except

# %%
a=10
b=20
try:
  if a<b:
    print(n)

# %%
a=10
b=20
try:
  if a<b:
    print(n)
except:
  print("錯誤產生")
# Out:
# 錯誤產生

# %% [markdown]
# ## 指定錯誤類別處理

# %%
a=10
b=20
try:
  if a<b:
    print(n)
except NameError:
  print("錯誤產生, 錯誤類別:",e)
except ZeroDivisionError:
  print("除以0錯誤")

# %%
a=10
b=20
try:
  if a>b:
    print(n)
except:
  print("錯誤產生")
else:
  print("沒錯誤會執行")
finally:
  print("不管有沒有錯一定執行")

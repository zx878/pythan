# %% [markdown]
# ### 函式(數)
# ### 傳統的寫法

# %%
import math
radius=eval(input("請輸入圓半徑:"))#將輸入字串變成數學計算型態
print("圓的面積為:",radius*radius*math.pi)
# Out:
# 請輸入圓半徑:10
# 圓的面積為: 314.1592653589793

# %% [markdown]
# ### 面積計算函示

# %%
import math
def cicle_area(radius): #圓面積
  area=radius*radius*math.pi
  return area

print(cicle_area(10))#半徑10
# Out:
# 314.1592653589793
